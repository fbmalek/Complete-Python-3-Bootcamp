# %%
my_list = [1,2,3]

# %%
my_list = ['String', 100,23,24.2]

# %%
len(my_list)
# Out:
# 4

# %%
mylist = ['one','two','three']

# %% [markdown]
# ## Slicing

# %%
mylist[0]
# Out:
# 'one'

# %%
mylist[1:]
# Out:
# ['two', 'three']

# %%
mylist + my_list
# Out:
# ['one', 'two', 'three', 'String', 100, 23, 24.2]

# %% [markdown]
# ## Concatnation

# %%
new_list = mylist + my_list

# %%
new_list
# Out:
# ['one', 'two', 'three', 'String', 100, 23, 24.2]

# %% [markdown]
# ## Mutation

# %%
new_list[0]='Bro'

# %%
new_list
# Out:
# ['Bro', 'two', 'three', 'String', 100, 23, 24.2]

# %% [markdown]
# # Instruction --> type in your Object. then press tab to get methods

# %% [markdown]
# ## append

# %% [markdown]
# new_list.append('Max Payne')

# %%
new_list
# Out:
# ['Bro', 'two', 'three', 'String', 100, 23, 24.2, 'Max Payne']

# %%
new_list.append('Mona Sax')

# %%
new_list
# Out:
# ['Bro', 'two', 'three', 'String', 100, 23, 24.2, 'Max Payne', 'Mona Sax']

# %% [markdown]
# ## pop

# %%
new_list.pop()
# Out:
# 'Mona Sax'

# %%
new_list
# Out:
# ['Bro', 'two', 'three', 'String', 100, 23, 24.2, 'Max Payne']

# %%
popped_item = new_list.pop()

# %%
popped_item
# Out:
# 'Max Payne'

# %% [markdown]
# ### slicing in pop

# %%
new_list.pop(0)
# Out:
# 'Bro'

# %%
new_list
# Out:
# ['two', 'three', 'String', 100, 23, 24.2]

# %% [markdown]
# ## Sort and Reverse methods

# %%
new_list = ['a','e','x','b','c']
num_list = [4,1,8,3]

# %%
new_list.sort()

# %%
new_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %% [markdown]
# ### commmon mistake
# sort() function does not return anything so you can not assign it to a new variable and expect anything. The type is also NoneType

# %%
my_sorted_list = new_list.sort()

# %%
my_sorted_list

# %%
type(my_sorted_list)
# Out:
# NoneType

# %%
None

# %%
# instead you can do this
new_list.sort()
my_sorted_list = new_list

# %%
my_sorted_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %%
num_list.sort()

# %%
num_list
# Out:
# [1, 3, 4, 8]

# %%
num_list.reverse()

# %%
num_list
# Out:
# [8, 4, 3, 1]
